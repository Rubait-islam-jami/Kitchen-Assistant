# %%
import pandas as pd

# %%
df=pd.read_csv("../data/processed/recipes_documents.csv")

# %%
df.head()
# Out:
#                                          name  \
# 0  arriba   baked winter squash mexican style
# 1            a bit different  breakfast pizza
# 2                   all in the kitchen  chili
# 3                          alouette  potatoes
# 4          amish  tomato ketchup  for canning
#
#                                          description  \
# 0  autumn is my favorite time of year to cook! th...
# 1  this recipe calls for the crust to be prebaked...
# 2  this modified version of 'mom's' chili was a h...
# 3  this is a super easy, great tasting, make ahea...
# 4  my dh's amish mother raised him on this recipe...
#
#                                          ingredients  \
# 0  ['winter squash', 'mexican seasoning', 'mixed ...
# 1  ['prepared pizza crust', 'sausage patty', 'egg...
# 2  ['ground beef', 'yellow onions', 'diced tomato...
# 3  ['spreadable cheese with garlic and herbs', 'n...
# 4  ['tomato juice', 'apple cider vinegar', 'sugar...
#
#                                                steps  \
# 0  ['make a choice and proceed with recipe', 'dep...
# 1  ['preheat oven to 425 degrees f', 'press dough...
# 2  ['brown ground beef in large pot', 'add choppe...
# 3  ['place potatoes in a large pot of lightly sal...
# 4  ['mix all ingredients& boil for 2 1 / 2 hours ...
#
#                                                 tags  minutes  \
# 0  ['60-minutes-or-less', 'time-to-make', 'course...       55
# 1  ['30-minutes-or-less', 'time-to-make', 'course...       30
# 2  ['time-to-make', 'course', 'preparation', 'mai...      130
# 3  ['60-minutes-or-less', 'time-to-make', 'course...       45
# 4  ['weeknight', 'time-to-make', 'course', 'main-...      190
#
#                                             document
# 0  \nRecipe Name: arriba   baked winter squash me...
# 1  \nRecipe Name: a bit different  breakfast pizz...
# 2  \nRecipe Name: all in the kitchen  chili\n\nDe...
# 3  \nRecipe Name: alouette  potatoes\n\nDescripti...
# 4  \nRecipe Name: amish  tomato ketchup  for cann...

# %%
# !python -m pip install minsearch
# Out:
# Requirement already satisfied: minsearch in c:\users\hp\desktop\kitchen-assistant\.venv\lib\site-packages (0.2.0)
# Requirement already satisfied: numpy in c:\users\hp\desktop\kitchen-assistant\.venv\lib\site-packages (from minsearch) (2.5.1)
# Requirement already satisfied: pandas in c:\users\hp\desktop\kitchen-assistant\.venv\lib\site-packages (from minsearch) (3.0.3)
# Requirement already satisfied: scikit-learn in c:\users\hp\desktop\kitchen-assistant\.venv\lib\site-packages (from minsearch) (1.9.0)
# Requirement already satisfied: stemlite>=0.1.0 in c:\users\hp\desktop\kitchen-assistant\.venv\lib\site-packages (from minsearch) (0.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hp\desktop\kitchen-assistant\.venv\lib\site-packages (from pandas->minsearch) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\hp\desktop\kitchen-assistant\.venv\lib\site-packages (from pandas->minsearch) (2026.3)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\hp\desktop\kitchen-assistant\.venv\lib\site-packages (from scikit-learn->minsearch) (1.18.0)
# Requirement already satisfied: joblib>=1.4.0 in c:\users\hp\desktop\kitchen-assistant\.venv\lib\site-packages (from scikit-learn->minsearch) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in c:\users\hp\desktop\kitchen-assistant\.venv\lib\site-packages (from scikit-learn->minsearch) (2.24.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in c:\users\hp\desktop\kitchen-assistant\.venv\lib\site-packages (from scikit-learn->minsearch) (3.6.0)
# Requirement already satisfied: six>=1.5 in c:\users\hp\desktop\kitchen-assistant\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas->minsearch) (1.17.0)
# [notice] A new release of pip is available: 24.0 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import minsearch
import pandas as pd

# %%
df=pd.read_csv("../data/processed/recipes_documents.csv")

# %%
df.head()
# Out:
#                                          name  \
# 0  arriba   baked winter squash mexican style
# 1            a bit different  breakfast pizza
# 2                   all in the kitchen  chili
# 3                          alouette  potatoes
# 4          amish  tomato ketchup  for canning
#
#                                          description  \
# 0  autumn is my favorite time of year to cook! th...
# 1  this recipe calls for the crust to be prebaked...
# 2  this modified version of 'mom's' chili was a h...
# 3  this is a super easy, great tasting, make ahea...
# 4  my dh's amish mother raised him on this recipe...
#
#                                          ingredients  \
# 0  ['winter squash', 'mexican seasoning', 'mixed ...
# 1  ['prepared pizza crust', 'sausage patty', 'egg...
# 2  ['ground beef', 'yellow onions', 'diced tomato...
# 3  ['spreadable cheese with garlic and herbs', 'n...
# 4  ['tomato juice', 'apple cider vinegar', 'sugar...
#
#                                                steps  \
# 0  ['make a choice and proceed with recipe', 'dep...
# 1  ['preheat oven to 425 degrees f', 'press dough...
# 2  ['brown ground beef in large pot', 'add choppe...
# 3  ['place potatoes in a large pot of lightly sal...
# 4  ['mix all ingredients& boil for 2 1 / 2 hours ...
#
#                                                 tags  minutes  \
# 0  ['60-minutes-or-less', 'time-to-make', 'course...       55
# 1  ['30-minutes-or-less', 'time-to-make', 'course...       30
# 2  ['time-to-make', 'course', 'preparation', 'mai...      130
# 3  ['60-minutes-or-less', 'time-to-make', 'course...       45
# 4  ['weeknight', 'time-to-make', 'course', 'main-...      190
#
#                                             document
# 0  \nRecipe Name: arriba   baked winter squash me...
# 1  \nRecipe Name: a bit different  breakfast pizz...
# 2  \nRecipe Name: all in the kitchen  chili\n\nDe...
# 3  \nRecipe Name: alouette  potatoes\n\nDescripti...
# 4  \nRecipe Name: amish  tomato ketchup  for cann...

# %%
text_fields=[
    "documents"
]
keyword_fields=[
    "name"
]

# %%
index = minsearch.Index(
    text_fields=text_fields,
    keyword_fields=keyword_fields
)

# %%
index.fit(df.to_dict(orient="records"))

# %%
results = index.search(
    query="vegetarian mexican squash",
    num_results=5
)

results
# Out:
# []
